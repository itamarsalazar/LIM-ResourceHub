# %%
import os

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
import sys

sys.path.insert(0, '/nfs/privileged/isalazar/projects/ultrasound-image-formation/')
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from exploration.EMBC2024.cross_experiment.train import load_model as load_nair_model
from exploration.advtraining.ifsr001_nair_advTrain import load_model as load_nairAdv_model
from strohm_train import load_model as load_strohm_model
from wang_train import load_wang_model
from src.US_data import LoadData_phantomLIM_ATSmodel539, LoadDataPICMUS
from src.beamforming_utils import make_pixel_grid_from_pos
from utils import downsample_channel_data, compute_metrics
from src.beamforming_DAS import make_bimg_das1
from pytorch_msssim import MS_SSIM
from skimage.restoration import denoise_nl_means
import cv2
from src.US_data import PlaneWaveData
import h5py
from scipy.signal import hilbert

# %%
import numpy as np
from skimage import measure, morphology

def perimeter_to_area_ratio(binary_mask):
    # Find contours of the shape
    contours = measure.find_contours(binary_mask, 0.5)

    # Calculate perimeter and area
    perimeter = measure.perimeter(contours[0])
    area = np.sum(binary_mask)

    # Calculate perimeter-to-area ratio
    ratio = perimeter / area
    return ratio

# def perimeter_to_area_ratio(binary_mask):
# 
#     # Find contours of the largest object
#     contours = measure.find_contours(largest_object_mask, 0.5)
# 
#     # Calculate perimeter and area
#     perimeter = measure.perimeter(contours[0])
#     area = np.sum(largest_object_mask)
# 
#     # Calculate perimeter-to-area ratio
#     ratio = perimeter / area
#     return ratio

# %%
class ShapeVariationDataLoader(PlaneWaveData):
    def __init__(self, h5_dir, h5_name, simu_name):
        h5filename = os.path.join(h5_dir, h5_name)
        print(h5filename)
        with h5py.File(h5filename, "r") as g:
            print(g.keys())
            f = g[simu_name]
            self.idata = np.expand_dims(np.array(f["signal"], dtype="float32"), 0)
            self.qdata = np.imag(hilbert(self.idata, axis=-1))
            self.angles = np.array([0])
            self.fc = np.array(f['fc']).item()
            self.fs = np.array(f['fs']).item()
            self.c = np.array(f['c']).item()
            self.time_zero = np.array([np.array(f['time_zero']).item()])
            self.phantom_xlims = [-0.02, 0.02]
            self.phantom_zlims = [0.03, 0.08]
            self.grid_xlims = [-0.02, 0.02]
            self.grid_zlims = [0.03, 0.08]
            self.fdemod = 0
            xs = np.squeeze(np.array(f['ele_pos']))
            self.ele_pos = np.array([xs, np.zeros_like(xs), np.zeros_like(xs)]).T
            # self.pos_lat = np.array(f['lat_pos']).item()
            # self.pos_ax = np.array(f['ax_pos']).item()
        super().validate()

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
this_dir = 'C:/Users/u_imagenes/PycharmProjects/ultrasound-image-formation/exploration/Journal2023/'
basic_dataset_dir = 'C:/Users/u_imagenes/PycharmProjects/ultrasound-image-formation/exploration/Journal2023/sample_data/'
h5_dataset_dir = f'{basic_dataset_dir}/naturalPerturbations/shape/v1.0'

# load model
epoch = 99
das_label = 'DAS'
# wang_label = 'wang_adv_eps0.008'
model_nair, _ = load_nair_model(model_dir=os.path.join(this_dir, "models", 'nair'),
                                epoch=epoch,
                                device=device)
model_strohm, _ = load_strohm_model(model_dir=os.path.join(this_dir, "models", 'strohm'),
                                    epoch=epoch,
                                    device=device)
model_wang, _, _, _, _ = load_wang_model(model_dir=os.path.join(this_dir, "models", 'wang'),
                                         epoch=epoch,
                                         num_downs=5,
                                         device=device)
model_nair.eval()
model_strohm.eval()
model_wang.eval()
print("")
# Out:
# Loading model 99...
# Model 99 loaded.
# Loading model 99...
# Model 99 loaded.
# Loading models 99...
# Generator 99 loaded.
# Discriminator 99 loaded.

# %%
inclusion_shape = 'triangle'
simu_name = 'simu00004'

h5name = "inclusion_%s.h5" % inclusion_shape
P = ShapeVariationDataLoader(h5_dir=h5_dataset_dir, h5_name=h5name, simu_name=simu_name)
max_value = np.max(np.abs(np.array([P.idata, P.qdata])))
P.idata = P.idata / max_value
P.qdata = P.qdata / max_value
# ------ Create grid
laterals = np.linspace(P.grid_xlims[0], P.grid_xlims[-1], 128)
depths = np.linspace(P.grid_zlims[0], P.grid_zlims[-1], 800)
grid_full = make_pixel_grid_from_pos(x_pos=laterals, z_pos=depths)

# channel_data_shape, depth_samples, offset = downsample_channel_data(copy.deepcopy(P),
#                                                                     nsamples=800,
#                                                                     device=device)
channel_data_shape = downsample_channel_data(copy.deepcopy(P),
                                             laterals=laterals,
                                             depths=depths,
                                             device=device)
channel_data_shape = channel_data_shape / channel_data_shape.abs().max()

extent_full = [P.grid_xlims[0] * 1e3, P.grid_xlims[-1] * 1e3,
               P.grid_zlims[-1] * 1e3, P.grid_zlims[0] * 1e3]
opts = {"extent": extent_full, "origin": "upper"}

# ------ DAS and models' reconstructions
# ------------------------------------------------------------------------------
das_phantom, _ = make_bimg_das1(copy.deepcopy(P), grid_full, device=device)
# ------------------------------------------------------------------------------
nair_phantom = model_nair(channel_data_shape)
# ------------------------------------------------------------------------------
strohm_phantom = model_strohm(channel_data_shape)
# ------------------------------------------------------------------------------
N, C, H, W = channel_data_shape.size()
z = torch.randn(N, 1, H, W).to(device)
wang_phantom = model_wang(torch.cat((channel_data_shape, z), dim=1))
# ------------------------------------------------------------------------------

output_in_bmode_format = lambda x: (x * 60 - 60).detach().cpu().numpy().squeeze()

nair_phantom = output_in_bmode_format(nair_phantom)
strohm_phantom = output_in_bmode_format(strohm_phantom)
wang_phantom = output_in_bmode_format(wang_phantom)

bmodes = {'DAS': das_phantom, 'NAIR': nair_phantom, 'STROHM': strohm_phantom, 'WANG': wang_phantom}
# Out:
# C:/Users/u_imagenes/PycharmProjects/ultrasound-image-formation/exploration/Journal2023/sample_data//naturalPerturbations/shape/v1.0\inclusion_triangle.h5
# <KeysViewHDF5 ['simu00001', 'simu00002', 'simu00003', 'simu00004']>

# %%
def calculate_iou(mask1, mask2):
    intersection = np.logical_and(mask1, mask2)
    union = np.logical_or(mask1, mask2)
    iou = np.sum(intersection) / np.sum(union)
    return iou

def create_triangle_mask(grid_full, vertices):
    # Create an empty mask
    triangle_mask = np.zeros(grid_full.shape[:2], dtype=bool)

    # Define vertices of the triangle
    v1, v2, v3 = vertices

    # Iterate over each pixel in the grid
    for i in range(grid_full.shape[0]):
        for j in range(grid_full.shape[1]):
            x = grid_full[i, j, 0]
            z = grid_full[i, j, 2]

            # Check if the pixel is inside the triangle using barycentric coordinates
            b1 = ((v2[1] - v3[1])*(x - v3[0]) + (v3[0] - v2[0])*(z - v3[1])) / \
                 ((v2[1] - v3[1])*(v1[0] - v3[0]) + (v3[0] - v2[0])*(v1[1] - v3[1]))
            b2 = ((v3[1] - v1[1])*(x - v3[0]) + (v1[0] - v3[0])*(z - v3[1])) / \
                 ((v2[1] - v3[1])*(v1[0] - v3[0]) + (v3[0] - v2[0])*(v1[1] - v3[1]))
            b3 = 1 - b1 - b2

            # Check if the pixel is inside the triangle
            if 0 <= b1 <= 1 and 0 <= b2 <= 1 and 0 <= b3 <= 1:
                triangle_mask[i, j] = True

    return triangle_mask

# %%
side = 8/1000
depth = 55/1000
height = (3**0.5)*side/2
vertices = [(0, depth-height/2), (-side/2, depth+height/2), (side/2, depth+height/2)]
roi_ref = create_triangle_mask(grid_full, vertices)

# %%
extent_full = [P.grid_xlims[0] * 1e3, P.grid_xlims[-1] * 1e3,
           P.grid_zlims[-1] * 1e3, P.grid_zlims[0] * 1e3]
opts = {"extent": extent_full, "origin": "upper"}

# %%
ncols = len(bmodes)
fig, ax = plt.subplots(nrows=1, ncols=ncols, figsize=(3 * ncols, 4))
for counter, name in enumerate(bmodes):
    ax[counter].imshow(bmodes[name], cmap="gray", vmin=-60, vmax=0, **opts)
ax[-1].imshow(roi_ref, cmap="gray", vmin=0, vmax=1, **opts)
plt.suptitle('%s' % h5name)
# Out:
# Text(0.5, 0.98, 'inclusion_triangle.h5')

# %%
from scipy import ndimage

# %%
# Initialize lists to store parameters and iou values
h_values = []
patch_size_values = []
patch_distance_values = []
threshold_values = []
name_values = []
iou_values = []

# Define parameter ranges
h_range = np.linspace(0.01, 0.21, 11)
patch_size_range = np.linspace(3, 15, 7)
patch_distance_range = np.linspace(3, 21, 10)
threshold_range = np.linspace(0.4, 0.7, 31)

# Iterate over parameter combinations
counter = 0
for h in h_range:
    for patch_size in patch_size_range:
        for patch_distance in patch_distance_range:
            for name in bmodes:
                bmode = bmodes[name]
                bmode_img = (bmode + 60) / 60
                smooth = denoise_nl_means(bmode_img,
                                            h=h,
                                            patch_size=int(patch_size),
                                            patch_distance=int(patch_distance),
                                            # sigma=sigma,
                                            preserve_range=True)
                print(f"({counter}/{11*7*10*4}) - hsname: {h5name}, h: {h}, patch_size: {patch_size}, patch_distance: {patch_distance}, bmf: {name}", end='')
                counter += 1
                for threshold in threshold_range:
                    print(".", end='')
                    mask = smooth<threshold
                    
                    labeled_mask, num_labels = measure.label(mask, connectivity=2, return_num=True)

                    if num_labels > 0:
                        largest_object_label = np.argmax(np.bincount(labeled_mask.flat)[1:]) + 1
                        largest_object_mask = (labeled_mask == largest_object_label)
                        filled_mask = ndimage.binary_fill_holes(largest_object_mask)
                    
                        iou = calculate_iou(roi_ref, filled_mask)
                    
                        # Append parameter values and iou to lists
                        h_values.append(h)
                        patch_size_values.append(patch_size)
                        patch_distance_values.append(patch_distance)
                        threshold_values.append(threshold)
                        name_values.append(name)
                        iou_values.append(iou)
                    else:
                        print("No labeled regions found in the mask.")
                    # largest_object_label = np.argmax(np.bincount(labeled_mask.flat)[1:]) + 1
                    # largest_object_mask = (labeled_mask == largest_object_label)
                    # filled_mask = ndimage.binary_fill_holes(largest_object_mask)
                    # 
                    # iou = calculate_iou(roi_ref, filled_mask)
                    
                    # # Append parameter values and iou to lists
                    # h_values.append(h)
                    # patch_size_values.append(patch_size)
                    # patch_distance_values.append(patch_distance)
                    # threshold_values.append(threshold)
                    # name_values.append(name)
                    # iou_values.append(iou)
                print(" ")

# Create DataFrame
data = {
    'h': h_values,
    'patch_size': patch_size_values,
    'patch_distance': patch_distance_values,
    'threshold': threshold_values,
    'name': name_values,
    'iou': iou_values
}

df = pd.DataFrame(data)
df.to_csv(f'grid_search_{h5name[:-4]}.csv', index=False)  # Set index=False to exclude row numbers
# Out:
# (0/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 3.0, bmf: DAS...............................
# (1/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 3.0, bmf: NAIR...............................
# (2/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 3.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (3/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 3.0, bmf: WANG...............................
# (4/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 5.0, bmf: DAS...............................
# (5/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 5.0, bmf: NAIR...............................
# (6/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 5.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (7/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 5.0, bmf: WANG...............................
# (8/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 7.0, bmf: DAS...............................
# (9/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 7.0, bmf: NAIR...............................
# (10/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 7.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (11/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 7.0, bmf: WANG...............................
# (12/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 9.0, bmf: DAS...............................
# (13/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 9.0, bmf: NAIR...............................
# (14/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 9.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (15/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 9.0, bmf: WANG...............................
# (16/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 11.0, bmf: DAS...............................
# (17/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 11.0, bmf: NAIR...............................
# (18/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 11.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (19/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 11.0, bmf: WANG...............................
# (20/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 13.0, bmf: DAS...............................
# (21/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 13.0, bmf: NAIR...............................
# (22/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 13.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (23/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 13.0, bmf: WANG...............................
# (24/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 15.0, bmf: DAS...............................
# (25/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 15.0, bmf: NAIR...............................
# (26/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 15.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (27/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 15.0, bmf: WANG...............................
# (28/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 17.0, bmf: DAS...............................
# (29/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 17.0, bmf: NAIR...............................
# (30/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 17.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (31/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 17.0, bmf: WANG...............................
# (32/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 19.0, bmf: DAS...............................
# (33/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 19.0, bmf: NAIR...............................
# (34/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 19.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (35/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 19.0, bmf: WANG...............................
# (36/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 21.0, bmf: DAS...............................
# (37/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 21.0, bmf: NAIR...............................
# (38/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 21.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (39/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 3.0, patch_distance: 21.0, bmf: WANG...............................
# (40/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 3.0, bmf: DAS...............................
# (41/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 3.0, bmf: NAIR...............................
# (42/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 3.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (43/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 3.0, bmf: WANG...............................
# (44/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 5.0, bmf: DAS...............................
# (45/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 5.0, bmf: NAIR...............................
# (46/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 5.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (47/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 5.0, bmf: WANG...............................
# (48/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 7.0, bmf: DAS...............................
# (49/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 7.0, bmf: NAIR...............................
# (50/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 7.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (51/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 7.0, bmf: WANG...............................
# (52/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 9.0, bmf: DAS...............................
# (53/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 9.0, bmf: NAIR...............................
# (54/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 9.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (55/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 9.0, bmf: WANG...............................
# (56/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 11.0, bmf: DAS...............................
# (57/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 11.0, bmf: NAIR...............................
# (58/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 11.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (59/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 11.0, bmf: WANG...............................
# (60/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 13.0, bmf: DAS...............................
# (61/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 13.0, bmf: NAIR...............................
# (62/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 13.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (63/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 13.0, bmf: WANG...............................
# (64/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 15.0, bmf: DAS...............................
# (65/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 15.0, bmf: NAIR...............................
# (66/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 15.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (67/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 15.0, bmf: WANG...............................
# (68/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 17.0, bmf: DAS...............................
# (69/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 17.0, bmf: NAIR...............................
# (70/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 17.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (71/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 17.0, bmf: WANG...............................
# (72/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 19.0, bmf: DAS...............................
# (73/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 19.0, bmf: NAIR...............................
# (74/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 19.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (75/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 19.0, bmf: WANG...............................
# (76/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 21.0, bmf: DAS...............................
# (77/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 21.0, bmf: NAIR...............................
# (78/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 21.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (79/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 5.0, patch_distance: 21.0, bmf: WANG...............................
# (80/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 3.0, bmf: DAS...............................
# (81/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 3.0, bmf: NAIR...............................
# (82/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 3.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (83/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 3.0, bmf: WANG...............................
# (84/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 5.0, bmf: DAS...............................
# (85/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 5.0, bmf: NAIR...............................
# (86/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 5.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (87/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 5.0, bmf: WANG...............................
# (88/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 7.0, bmf: DAS...............................
# (89/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 7.0, bmf: NAIR...............................
# (90/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 7.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (91/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 7.0, bmf: WANG...............................
# (92/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 9.0, bmf: DAS...............................
# (93/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 9.0, bmf: NAIR...............................
# (94/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 9.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (95/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 9.0, bmf: WANG...............................
# (96/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 11.0, bmf: DAS...............................
# (97/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 11.0, bmf: NAIR...............................
# (98/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 11.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (99/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 11.0, bmf: WANG...............................
# (100/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 13.0, bmf: DAS...............................
# (101/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 13.0, bmf: NAIR...............................
# (102/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 13.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (103/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 13.0, bmf: WANG...............................
# (104/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 15.0, bmf: DAS...............................
# (105/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 15.0, bmf: NAIR...............................
# (106/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 15.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (107/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 15.0, bmf: WANG...............................
# (108/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 17.0, bmf: DAS...............................
# (109/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 17.0, bmf: NAIR...............................
# (110/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 17.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (111/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 17.0, bmf: WANG...............................
# (112/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 19.0, bmf: DAS...............................
# (113/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 19.0, bmf: NAIR...............................
# (114/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 19.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (115/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 19.0, bmf: WANG...............................
# (116/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 21.0, bmf: DAS...............................
# (117/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 21.0, bmf: NAIR...............................
# (118/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 21.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (119/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 7.0, patch_distance: 21.0, bmf: WANG...............................
# (120/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 3.0, bmf: DAS...............................
# (121/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 3.0, bmf: NAIR...............................
# (122/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 3.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (123/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 3.0, bmf: WANG...............................
# (124/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 5.0, bmf: DAS...............................
# (125/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 5.0, bmf: NAIR...............................
# (126/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 5.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (127/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 5.0, bmf: WANG...............................
# (128/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 7.0, bmf: DAS...............................
# (129/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 7.0, bmf: NAIR...............................
# (130/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 7.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (131/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 7.0, bmf: WANG...............................
# (132/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 9.0, bmf: DAS...............................
# (133/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 9.0, bmf: NAIR...............................
# (134/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 9.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (135/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 9.0, bmf: WANG...............................
# (136/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 11.0, bmf: DAS...............................
# (137/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 11.0, bmf: NAIR...............................
# (138/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 11.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (139/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 11.0, bmf: WANG...............................
# (140/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 13.0, bmf: DAS...............................
# (141/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 13.0, bmf: NAIR...............................
# (142/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 13.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (143/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 13.0, bmf: WANG...............................
# (144/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 15.0, bmf: DAS...............................
# (145/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 15.0, bmf: NAIR...............................
# (146/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 15.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (147/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 15.0, bmf: WANG...............................
# (148/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 17.0, bmf: DAS...............................
# (149/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 17.0, bmf: NAIR...............................
# (150/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 17.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (151/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 17.0, bmf: WANG...............................
# (152/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 19.0, bmf: DAS...............................
# (153/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 19.0, bmf: NAIR...............................
# (154/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 19.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (155/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 19.0, bmf: WANG...............................
# (156/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 21.0, bmf: DAS...............................
# (157/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 21.0, bmf: NAIR...............................
# (158/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 21.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (159/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 9.0, patch_distance: 21.0, bmf: WANG...............................
# (160/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 3.0, bmf: DAS...............................
# (161/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 3.0, bmf: NAIR...............................
# (162/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 3.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (163/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 3.0, bmf: WANG...............................
# (164/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 5.0, bmf: DAS...............................
# (165/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 5.0, bmf: NAIR...............................
# (166/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 5.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (167/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 5.0, bmf: WANG...............................
# (168/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 7.0, bmf: DAS...............................
# (169/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 7.0, bmf: NAIR...............................
# (170/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 7.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (171/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 7.0, bmf: WANG...............................
# (172/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 9.0, bmf: DAS...............................
# (173/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 9.0, bmf: NAIR...............................
# (174/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 9.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (175/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 9.0, bmf: WANG...............................
# (176/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 11.0, bmf: DAS...............................
# (177/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 11.0, bmf: NAIR...............................
# (178/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 11.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (179/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 11.0, bmf: WANG...............................
# (180/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 13.0, bmf: DAS...............................
# (181/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 13.0, bmf: NAIR...............................
# (182/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 13.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (183/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 13.0, bmf: WANG...............................
# (184/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 15.0, bmf: DAS...............................
# (185/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 15.0, bmf: NAIR...............................
# (186/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 15.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (187/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 15.0, bmf: WANG...............................
# (188/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 17.0, bmf: DAS...............................
# (189/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 17.0, bmf: NAIR...............................
# (190/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 17.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (191/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 17.0, bmf: WANG...............................
# (192/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 19.0, bmf: DAS...............................
# (193/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 19.0, bmf: NAIR...............................
# (194/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 19.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (195/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 19.0, bmf: WANG...............................
# (196/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 21.0, bmf: DAS...............................
# (197/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 21.0, bmf: NAIR...............................
# (198/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 21.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ............................
# (199/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 11.0, patch_distance: 21.0, bmf: WANG...............................
# (200/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 3.0, bmf: DAS...............................
# (201/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 3.0, bmf: NAIR...............................
# (202/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 3.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (203/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 3.0, bmf: WANG...............................
# (204/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 5.0, bmf: DAS...............................
# (205/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 5.0, bmf: NAIR...............................
# (206/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 5.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (207/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 5.0, bmf: WANG...............................
# (208/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 7.0, bmf: DAS...............................
# (209/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 7.0, bmf: NAIR...............................
# (210/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 7.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (211/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 7.0, bmf: WANG...............................
# (212/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 9.0, bmf: DAS...............................
# (213/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 9.0, bmf: NAIR...............................
# (214/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 9.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (215/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 9.0, bmf: WANG...............................
# (216/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 11.0, bmf: DAS...............................
# (217/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 11.0, bmf: NAIR...............................
# (218/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 11.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (219/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 11.0, bmf: WANG...............................
# (220/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 13.0, bmf: DAS...............................
# (221/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 13.0, bmf: NAIR...............................
# (222/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 13.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (223/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 13.0, bmf: WANG...............................
# (224/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 15.0, bmf: DAS...............................
# (225/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 15.0, bmf: NAIR...............................
# (226/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 15.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (227/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 15.0, bmf: WANG...............................
# (228/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 17.0, bmf: DAS...............................
# (229/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 17.0, bmf: NAIR...............................
# (230/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 17.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (231/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 17.0, bmf: WANG...............................
# (232/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 19.0, bmf: DAS...............................
# (233/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 19.0, bmf: NAIR...............................
# (234/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 19.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (235/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 19.0, bmf: WANG...............................
# (236/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 21.0, bmf: DAS...............................
# (237/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 21.0, bmf: NAIR...............................
# (238/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 21.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (239/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 13.0, patch_distance: 21.0, bmf: WANG...............................
# (240/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 3.0, bmf: DAS...............................
# (241/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 3.0, bmf: NAIR...............................
# (242/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 3.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (243/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 3.0, bmf: WANG...............................
# (244/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 5.0, bmf: DAS...............................
# (245/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 5.0, bmf: NAIR...............................
# (246/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 5.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (247/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 5.0, bmf: WANG...............................
# (248/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 7.0, bmf: DAS...............................
# (249/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 7.0, bmf: NAIR...............................
# (250/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 7.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (251/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 7.0, bmf: WANG...............................
# (252/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 9.0, bmf: DAS...............................
# (253/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 9.0, bmf: NAIR...............................
# (254/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 9.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (255/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 9.0, bmf: WANG...............................
# (256/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 11.0, bmf: DAS...............................
# (257/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 11.0, bmf: NAIR...............................
# (258/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 11.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (259/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 11.0, bmf: WANG...............................
# (260/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 13.0, bmf: DAS...............................
# (261/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 13.0, bmf: NAIR...............................
# (262/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 13.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (263/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 13.0, bmf: WANG...............................
# (264/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 15.0, bmf: DAS...............................
# (265/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 15.0, bmf: NAIR...............................
# (266/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 15.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (267/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 15.0, bmf: WANG...............................
# (268/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 17.0, bmf: DAS...............................
# (269/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 17.0, bmf: NAIR...............................
# (270/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 17.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (271/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 17.0, bmf: WANG...............................
# (272/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 19.0, bmf: DAS...............................
# (273/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 19.0, bmf: NAIR...............................
# (274/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 19.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (275/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 19.0, bmf: WANG...............................
# (276/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 21.0, bmf: DAS...............................
# (277/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 21.0, bmf: NAIR...............................
# (278/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 21.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (279/3080) - hsname: inclusion_triangle.h5, h: 0.01, patch_size: 15.0, patch_distance: 21.0, bmf: WANG...............................
# (280/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 3.0, bmf: DAS...............................
# (281/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 3.0, bmf: NAIR...............................
# (282/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 3.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (283/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 3.0, bmf: WANG...............................
# (284/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 5.0, bmf: DAS...............................
# (285/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 5.0, bmf: NAIR...............................
# (286/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 5.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (287/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 5.0, bmf: WANG...............................
# (288/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 7.0, bmf: DAS...............................
# (289/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 7.0, bmf: NAIR...............................
# (290/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 7.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (291/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 7.0, bmf: WANG...............................
# (292/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 9.0, bmf: DAS...............................
# (293/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 9.0, bmf: NAIR...............................
# (294/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 9.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ..........................
# (295/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 9.0, bmf: WANG...............................
# (296/3080) - hsname: inclusion_triangle.h5, h: 0.03, patch_size: 3.0, patch_distance: 11.0, bmf: DAS...............................
# ...
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .................
# (3040/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 3.0, bmf: DAS.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (3041/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 3.0, bmf: NAIR...............................
# (3042/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 3.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (3043/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 3.0, bmf: WANG...............................
# (3044/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 5.0, bmf: DAS.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...........................
# (3045/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 5.0, bmf: NAIR...............................
# (3046/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 5.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .........................
# (3047/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 5.0, bmf: WANG.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .............................
# (3048/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 7.0, bmf: DAS.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ..........................
# (3049/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 7.0, bmf: NAIR...............................
# (3050/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 7.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ........................
# (3051/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 7.0, bmf: WANG.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ..........................
# (3052/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 9.0, bmf: DAS.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ..........................
# (3053/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 9.0, bmf: NAIR...............................
# (3054/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 9.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .......................
# (3055/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 9.0, bmf: WANG.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .........................
# (3056/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 11.0, bmf: DAS.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ........................
# (3057/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 11.0, bmf: NAIR...............................
# (3058/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 11.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ......................
# (3059/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 11.0, bmf: WANG.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .......................
# (3060/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 13.0, bmf: DAS.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ......................
# (3061/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 13.0, bmf: NAIR...............................
# (3062/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 13.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ....................
# (3063/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 13.0, bmf: WANG.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .....................
# (3064/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 15.0, bmf: DAS.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ....................
# (3065/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 15.0, bmf: NAIR...............................
# (3066/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 15.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ..................
# (3067/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 15.0, bmf: WANG.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ....................
# (3068/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 17.0, bmf: DAS.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ..................
# (3069/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 17.0, bmf: NAIR...............................
# (3070/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 17.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .................
# (3071/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 17.0, bmf: WANG.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...................
# (3072/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 19.0, bmf: DAS.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .................
# (3073/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 19.0, bmf: NAIR...............................
# (3074/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 19.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ...............
# (3075/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 19.0, bmf: WANG.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ..................
# (3076/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 21.0, bmf: DAS.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ................
# (3077/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 21.0, bmf: NAIR...............................
# (3078/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 21.0, bmf: STROHM.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# ..............
# (3079/3080) - hsname: inclusion_triangle.h5, h: 0.21, patch_size: 15.0, patch_distance: 21.0, bmf: WANG.No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .No labeled regions found in the mask.
# .................

# %%
# labeled_mask, num_labels = measure.label(mask, connectivity=2, return_num=True)
# largest_object_label = np.argmax(np.bincount(labeled_mask.flat)[1:]) + 1
# largest_object_mask = (labeled_mask == largest_object_label)
# filled_mask = ndimage.binary_fill_holes(largest_object_mask)
# val = perimeter_to_area_ratio(filled_mask)

# %%
df[df['iou'] == df['iou'].max()]
# Out:
#           h  patch_size  patch_distance  threshold  name       iou
# 27771  0.07         7.0             5.0       0.66  NAIR  0.759756

# %%
df.groupby('name')['iou'].max()
# Out:
# name
# DAS       0.730061
# NAIR      0.759756
# STROHM    0.729537
# WANG      0.728070
# Name: iou, dtype: float64

# %%
max_iou_index = df.groupby('name')['iou'].idxmax()
result_df = df.loc[max_iou_index]
result_df
# Out:
#           h  patch_size  patch_distance  threshold    name       iou
# 77962  0.21         3.0             5.0       0.61     DAS  0.730061
# 27771  0.07         7.0             5.0       0.66    NAIR  0.759756
# 32922  0.07        15.0            11.0       0.65  STROHM  0.729537
# 31993  0.07        13.0            15.0       0.61    WANG  0.728070

# %%
result_df['dice'] = 2*result_df['iou']/(1+result_df['iou'])
result_df
# Out:
#           h  patch_size  patch_distance  threshold    name       iou      dice
# 77962  0.21         3.0             5.0       0.61     DAS  0.730061  0.843972
# 27771  0.07         7.0             5.0       0.66    NAIR  0.759756  0.863479
# 32922  0.07        15.0            11.0       0.65  STROHM  0.729537  0.843621
# 31993  0.07        13.0            15.0       0.61    WANG  0.728070  0.842640
