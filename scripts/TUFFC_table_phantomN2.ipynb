# %%
import os

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
import sys

sys.path.insert(0, '/nfs/privileged/isalazar/projects/ultrasound-image-formation/')
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from exploration.EMBC2024.cross_experiment.train import load_model as load_nair_model
from strohm_train import load_model as load_strohm_model
from wang_train import load_wang_model
from src.US_data import LoadData_phantomLIM_ATSmodel539
from src.beamforming_utils import make_pixel_grid_from_pos
from utils import downsample_channel_data
from src.beamforming_DAS import make_bimg_das1
from skimage.restoration import denoise_nl_means
import cv2

# %%
def calculate_iou(mask1, mask2):
    intersection = np.logical_and(mask1, mask2)
    union = np.logical_or(mask1, mask2)
    iou = np.sum(intersection) / np.sum(union)
    return iou

def get_data_from_name(h5name):
    if h5name=='IS_L11-4v_data2_RF.h5':
        depths_ini_list = np.linspace(0, 80, 160)
        depth_ini = depths_ini_list[65]
        roi_ref = cv2.imread('data_2_frame_65.png', cv2.IMREAD_GRAYSCALE)

    elif h5name=='IS_L11-4v_data3_RF.h5':
        depths_ini_list = np.linspace(0, 80, 80)
        depth_ini = depths_ini_list[36]
        roi_ref = cv2.imread('data_3_frame_64.png', cv2.IMREAD_GRAYSCALE)

    elif h5name=='IS_L11-4v_data1_RF.h5':
        depths_ini_list = np.linspace(0, 80, 80)
        depth_ini = depths_ini_list[36]
        roi_ref = cv2.imread('data_1_frame_36.png', cv2.IMREAD_GRAYSCALE)
    else:
        raise NotImplementedError

    roi_ref = np.array(roi_ref)/255
    
    return depth_ini, roi_ref

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
this_dir = 'C:/Users/u_imagenes/PycharmProjects/ultrasound-image-formation/exploration/Journal2023/'
basic_dataset_dir = 'C:/Users/u_imagenes/PycharmProjects/ultrasound-image-formation/exploration/Journal2023/sample_data/'
h5_dataset_dir = f'{basic_dataset_dir}/verasonics'

# load model
epoch = 99
das_label = 'DAS'
# wang_label = 'wang_adv_eps0.008'
model_nair, _ = load_nair_model(model_dir=os.path.join(this_dir, "models", 'nair'),
                                epoch=epoch,
                                device=device)
model_strohm, _ = load_strohm_model(model_dir=os.path.join(this_dir, "models", 'strohm'),
                                    epoch=epoch,
                                    device=device)
model_wang, _, _, _, _ = load_wang_model(model_dir=os.path.join(this_dir, "models", 'wang'),
                                         epoch=epoch,
                                         num_downs=5,
                                         device=device)
model_nair.eval()
model_strohm.eval()
model_wang.eval()
print("")
# Out:
# Loading model 99...
# Model 99 loaded.
# Loading model 99...
# Model 99 loaded.
# Loading models 99...
# Generator 99 loaded.
# Discriminator 99 loaded.

# %%
h5name = 'IS_L11-4v_data3_RF.h5'

# %%
depth_ini, roi_ref = get_data_from_name(h5name)
P = LoadData_phantomLIM_ATSmodel539(h5_dir=h5_dataset_dir, h5_name=h5name)
max_value = np.max(np.abs(np.array([P.idata, P.qdata])))
P.idata = P.idata / max_value
P.qdata = P.qdata / max_value

laterals = np.linspace(P.phantom_xlims[0], P.phantom_xlims[-1], num=128)
depths = np.linspace(depth_ini, depth_ini+50, num=800) / 1000
P.grid_xlims = P.phantom_xlims
P.grid_zlims = np.array([depth_ini, depth_ini+50]) / 1000
# Downsample channel data
channel_data_phantom = downsample_channel_data(copy.deepcopy(P),
                                               laterals=laterals,
                                               depths=depths,
                                               device=device)
channel_data_phantom = channel_data_phantom / channel_data_phantom.abs().max()
laterals = np.linspace(P.grid_xlims[0], P.grid_xlims[-1], 128)
grid_full = make_pixel_grid_from_pos(x_pos=laterals, z_pos=depths)

das_phantom, _ = make_bimg_das1(copy.deepcopy(P), grid_full, device=device)
nair_phantom = model_nair(channel_data_phantom)
strohm_phantom = model_strohm(channel_data_phantom)
N, C, H, W = channel_data_phantom.size()
z = torch.randn(N, 1, H, W).to(device)
wang_phantom = model_wang(torch.cat((channel_data_phantom, z), dim=1))

output_in_bmode_format = lambda x: np.clip((x * 60 - 60).detach().cpu().numpy().squeeze(), a_min=-60, a_max=0)

das_phantom  = np.clip(das_phantom, a_min=-60, a_max=0)
nair_phantom = output_in_bmode_format(nair_phantom)
strohm_phantom = output_in_bmode_format(strohm_phantom)
wang_phantom = output_in_bmode_format(wang_phantom)
bmodes = {'DAS': das_phantom, 'NAIR': nair_phantom, 'STROHM': strohm_phantom, 'WANG': wang_phantom}
# Out:
# Dataset successfully loaded

# %%
xctr1, zctr1 = -3/1000, 50.25/1000
xctr2, zctr2 = 17/1000, 50.25/1000
dist1 = np.sqrt((grid_full[:, :, 0] - xctr1) ** 2 + (grid_full[:, :, 2] - zctr1) ** 2)
dist2 = np.sqrt((grid_full[:, :, 0] - xctr2) ** 2 + (grid_full[:, :, 2] - zctr2) ** 2)

r = 7.5/1000
r0 = r - 2/1000
r1 = r + 2/1000
r2 = np.sqrt(r0**2 + r1**2)

roi_cyst1 = dist1 <=r
roi_in1 = dist1 <= r0
roi_out1 = (r1 <= dist1) * (dist1 <= r2)

roi_cyst2 = dist2 <=r
roi_in2 = dist2 <= r0
roi_out2 = (r1 <= dist2) * (dist2 <= r2)

# %%
extent_full = [P.grid_xlims[0] * 1e3, P.grid_xlims[-1] * 1e3,
           P.grid_zlims[-1] * 1e3, P.grid_zlims[0] * 1e3]
opts = {"extent": extent_full, "origin": "upper"}

# %%
ncols = len(bmodes)
fig, ax = plt.subplots(nrows=1, ncols=ncols+1, figsize=(3 * (ncols+1), 4))
for counter, name in enumerate(bmodes):
    ax[counter].imshow(bmodes[name], cmap="gray", vmin=-60, vmax=0, **opts)
    ax[counter].contour(roi_cyst1, [0.5], colors="r", alpha=0.1, **opts)
    # ax[counter].contour(roi_in1, [0.5], colors="c", **opts)
    # ax[counter].contour(roi_out1, [0.5], colors="m", **opts)
    ax[counter].contour(roi_cyst2, [0.5], colors="r", alpha=0.1, **opts)
    # ax[counter].contour(roi_in2, [0.5], colors="c", **opts)
    # ax[counter].contour(roi_out2, [0.5], colors="m", **opts)
    ax[counter].set_title(name)
ax[-1].imshow(roi_ref, cmap="gray", vmin=0, vmax=1, **opts)
ax[-1].contour(roi_cyst1, [0.5], colors="r", **opts)
ax[-1].contour(roi_in1, [0.5], colors="c", **opts)
ax[-1].contour(roi_out1, [0.5], colors="m", **opts)
ax[-1].contour(roi_cyst2, [0.5], colors="r", **opts)
ax[-1].contour(roi_in2, [0.5], colors="c", **opts)
ax[-1].contour(roi_out2, [0.5], colors="m", **opts)
plt.suptitle('%s' % h5name)
# Out:
# Text(0.5, 0.98, 'IS_L11-4v_data3_RF.h5')

# %% [markdown]
# ##### Contrast

# %%
def contrast(img1, img2):
    return 20 * np.log10(img1.mean() / img2.mean())

# %%
for bmf in bmodes:
    bmode = bmodes[bmf]
    env = 10**(bmode/20)
    env_in = env[roi_in1]
    env_out = env[roi_out1]
    contrast_value = contrast(env_in, env_out)
    print(f'{bmf}: {contrast_value}')
# Out:
# DAS: -5.934332609176636
# NAIR: -6.616586446762085
# STROHM: -5.144098997116089
# WANG: -6.143803000450134

# %%
for bmf in bmodes:
    bmode = bmodes[bmf]
    env = 10**(bmode/20)
    env_in = env[roi_in2]
    env_out = env[roi_out2]
    contrast_value = contrast(env_in, env_out)
    print(f'{bmf}: {contrast_value}')
# Out:
# DAS: -10.612603425979614
# NAIR: -18.253448009490967
# STROHM: -13.650918006896973
# WANG: -13.397679328918457

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3, 4))
ax.imshow((roi_cyst1 | roi_cyst2), cmap="gray", vmin=0, vmax=1, **opts)

# %% [markdown]
# #### IoU

# %%
# Initialize lists to store parameters and iou values
h_values = []
patch_size_values = []
patch_distance_values = []
threshold_values = []
name_values = []
iou_values = []

# Define parameter ranges
h_range = np.linspace(0.01, 0.21, 11)
patch_size_range = np.linspace(3, 15, 7)
patch_distance_range = np.linspace(3, 21, 10)
threshold_range = np.linspace(0.4, 0.7, 31)

# Iterate over parameter combinations
counter = 0
for h in h_range:
    for patch_size in patch_size_range:
        for patch_distance in patch_distance_range:
            for name in bmodes:
                bmode = bmodes[name]
                bmode_img = (bmode + 60) / 60
                smooth = denoise_nl_means(bmode_img,
                                            h=h,
                                            patch_size=int(patch_size),
                                            patch_distance=int(patch_distance),
                                            # sigma=sigma,
                                            preserve_range=True)
                print(f"({counter}/{11*7*10*4}) - hsname: {h5name}, h: {h}, patch_size: {patch_size}, patch_distance: {patch_distance}, bmf: {name}", end='')
                counter += 1
                for threshold in threshold_range:
                    print(".", end='')
                    roi_comp = smooth<threshold
                    iou = calculate_iou((roi_cyst1 | roi_cyst2), roi_comp)

                    # Append parameter values and iou to lists
                    h_values.append(h)
                    patch_size_values.append(patch_size)
                    patch_distance_values.append(patch_distance)
                    threshold_values.append(threshold)
                    name_values.append(name)
                    iou_values.append(iou)
                print(" ")

# Create DataFrame
data = {
    'h': h_values,
    'patch_size': patch_size_values,
    'patch_distance': patch_distance_values,
    'threshold': threshold_values,
    'name': name_values,
    'iou': iou_values
}

df = pd.DataFrame(data)
df.to_csv(f'grid_search_{h5name[:-4]}.csv', index=False)  # Set index=False to exclude row numbers
# Out:
# (0/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 3.0, bmf: DAS...............................
# (1/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 3.0, bmf: NAIR...............................
# (2/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 3.0, bmf: STROHM...............................
# (3/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 3.0, bmf: WANG...............................
# (4/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 5.0, bmf: DAS...............................
# (5/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 5.0, bmf: NAIR...............................
# (6/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 5.0, bmf: STROHM...............................
# (7/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 5.0, bmf: WANG...............................
# (8/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 7.0, bmf: DAS...............................
# (9/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 7.0, bmf: NAIR...............................
# (10/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 7.0, bmf: STROHM...............................
# (11/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 7.0, bmf: WANG...............................
# (12/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 9.0, bmf: DAS...............................
# (13/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 9.0, bmf: NAIR...............................
# (14/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 9.0, bmf: STROHM...............................
# (15/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 9.0, bmf: WANG...............................
# (16/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 11.0, bmf: DAS...............................
# (17/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 11.0, bmf: NAIR...............................
# (18/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 11.0, bmf: STROHM...............................
# (19/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 11.0, bmf: WANG...............................
# (20/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 13.0, bmf: DAS...............................
# (21/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 13.0, bmf: NAIR...............................
# (22/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 13.0, bmf: STROHM...............................
# (23/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 13.0, bmf: WANG...............................
# (24/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 15.0, bmf: DAS...............................
# (25/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 15.0, bmf: NAIR...............................
# (26/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 15.0, bmf: STROHM...............................
# (27/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 15.0, bmf: WANG...............................
# (28/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 17.0, bmf: DAS...............................
# (29/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 17.0, bmf: NAIR...............................
# (30/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 17.0, bmf: STROHM...............................
# (31/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 17.0, bmf: WANG...............................
# (32/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 19.0, bmf: DAS...............................
# (33/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 19.0, bmf: NAIR...............................
# (34/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 19.0, bmf: STROHM...............................
# (35/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 19.0, bmf: WANG...............................
# (36/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 21.0, bmf: DAS...............................
# (37/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 21.0, bmf: NAIR...............................
# (38/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 21.0, bmf: STROHM...............................
# (39/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 3.0, patch_distance: 21.0, bmf: WANG...............................
# (40/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 3.0, bmf: DAS...............................
# (41/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 3.0, bmf: NAIR...............................
# (42/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 3.0, bmf: STROHM...............................
# (43/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 3.0, bmf: WANG...............................
# (44/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 5.0, bmf: DAS...............................
# (45/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 5.0, bmf: NAIR...............................
# (46/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 5.0, bmf: STROHM...............................
# (47/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 5.0, bmf: WANG...............................
# (48/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 7.0, bmf: DAS...............................
# (49/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 7.0, bmf: NAIR...............................
# (50/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 7.0, bmf: STROHM...............................
# (51/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 7.0, bmf: WANG...............................
# (52/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 9.0, bmf: DAS...............................
# (53/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 9.0, bmf: NAIR...............................
# (54/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 9.0, bmf: STROHM...............................
# (55/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 9.0, bmf: WANG...............................
# (56/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 11.0, bmf: DAS...............................
# (57/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 11.0, bmf: NAIR...............................
# (58/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 11.0, bmf: STROHM...............................
# (59/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 11.0, bmf: WANG...............................
# (60/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 13.0, bmf: DAS...............................
# (61/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 13.0, bmf: NAIR...............................
# (62/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 13.0, bmf: STROHM...............................
# (63/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 13.0, bmf: WANG...............................
# (64/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 15.0, bmf: DAS...............................
# (65/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 15.0, bmf: NAIR...............................
# (66/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 15.0, bmf: STROHM...............................
# (67/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 15.0, bmf: WANG...............................
# (68/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 17.0, bmf: DAS...............................
# (69/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 17.0, bmf: NAIR...............................
# (70/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 17.0, bmf: STROHM...............................
# (71/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 17.0, bmf: WANG...............................
# (72/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 19.0, bmf: DAS...............................
# (73/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 19.0, bmf: NAIR...............................
# (74/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 19.0, bmf: STROHM...............................
# (75/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 19.0, bmf: WANG...............................
# (76/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 21.0, bmf: DAS...............................
# (77/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 21.0, bmf: NAIR...............................
# (78/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 21.0, bmf: STROHM...............................
# (79/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 5.0, patch_distance: 21.0, bmf: WANG...............................
# (80/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 3.0, bmf: DAS...............................
# (81/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 3.0, bmf: NAIR...............................
# (82/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 3.0, bmf: STROHM...............................
# (83/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 3.0, bmf: WANG...............................
# (84/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 5.0, bmf: DAS...............................
# (85/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 5.0, bmf: NAIR...............................
# (86/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 5.0, bmf: STROHM...............................
# (87/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 5.0, bmf: WANG...............................
# (88/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 7.0, bmf: DAS...............................
# (89/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 7.0, bmf: NAIR...............................
# (90/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 7.0, bmf: STROHM...............................
# (91/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 7.0, bmf: WANG...............................
# (92/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 9.0, bmf: DAS...............................
# (93/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 9.0, bmf: NAIR...............................
# (94/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 9.0, bmf: STROHM...............................
# (95/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 9.0, bmf: WANG...............................
# (96/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 11.0, bmf: DAS...............................
# (97/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 11.0, bmf: NAIR...............................
# (98/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 11.0, bmf: STROHM...............................
# (99/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 11.0, bmf: WANG...............................
# (100/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 13.0, bmf: DAS...............................
# (101/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 13.0, bmf: NAIR...............................
# (102/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 13.0, bmf: STROHM...............................
# (103/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 13.0, bmf: WANG...............................
# (104/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 15.0, bmf: DAS...............................
# (105/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 15.0, bmf: NAIR...............................
# (106/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 15.0, bmf: STROHM...............................
# (107/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 15.0, bmf: WANG...............................
# (108/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 17.0, bmf: DAS...............................
# (109/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 17.0, bmf: NAIR...............................
# (110/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 17.0, bmf: STROHM...............................
# (111/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 17.0, bmf: WANG...............................
# (112/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 19.0, bmf: DAS...............................
# (113/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 19.0, bmf: NAIR...............................
# (114/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 19.0, bmf: STROHM...............................
# (115/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 19.0, bmf: WANG...............................
# (116/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 21.0, bmf: DAS...............................
# (117/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 21.0, bmf: NAIR...............................
# (118/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 21.0, bmf: STROHM...............................
# (119/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 7.0, patch_distance: 21.0, bmf: WANG...............................
# (120/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 3.0, bmf: DAS...............................
# (121/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 3.0, bmf: NAIR...............................
# (122/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 3.0, bmf: STROHM...............................
# (123/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 3.0, bmf: WANG...............................
# (124/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 5.0, bmf: DAS...............................
# (125/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 5.0, bmf: NAIR...............................
# (126/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 5.0, bmf: STROHM...............................
# (127/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 5.0, bmf: WANG...............................
# (128/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 7.0, bmf: DAS...............................
# (129/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 7.0, bmf: NAIR...............................
# (130/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 7.0, bmf: STROHM...............................
# (131/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 7.0, bmf: WANG...............................
# (132/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 9.0, bmf: DAS...............................
# (133/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 9.0, bmf: NAIR...............................
# (134/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 9.0, bmf: STROHM...............................
# (135/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 9.0, bmf: WANG...............................
# (136/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 11.0, bmf: DAS...............................
# (137/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 11.0, bmf: NAIR...............................
# (138/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 11.0, bmf: STROHM...............................
# (139/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 11.0, bmf: WANG...............................
# (140/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 13.0, bmf: DAS...............................
# (141/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 13.0, bmf: NAIR...............................
# (142/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 13.0, bmf: STROHM...............................
# (143/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 13.0, bmf: WANG...............................
# (144/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 15.0, bmf: DAS...............................
# (145/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 15.0, bmf: NAIR...............................
# (146/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 15.0, bmf: STROHM...............................
# (147/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 15.0, bmf: WANG...............................
# (148/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 17.0, bmf: DAS...............................
# (149/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 17.0, bmf: NAIR...............................
# (150/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 17.0, bmf: STROHM...............................
# (151/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 17.0, bmf: WANG...............................
# (152/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 19.0, bmf: DAS...............................
# (153/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 19.0, bmf: NAIR...............................
# (154/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 19.0, bmf: STROHM...............................
# (155/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 19.0, bmf: WANG...............................
# (156/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 21.0, bmf: DAS...............................
# (157/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 21.0, bmf: NAIR...............................
# (158/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 21.0, bmf: STROHM...............................
# (159/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 9.0, patch_distance: 21.0, bmf: WANG...............................
# (160/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 3.0, bmf: DAS...............................
# (161/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 3.0, bmf: NAIR...............................
# (162/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 3.0, bmf: STROHM...............................
# (163/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 3.0, bmf: WANG...............................
# (164/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 5.0, bmf: DAS...............................
# (165/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 5.0, bmf: NAIR...............................
# (166/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 5.0, bmf: STROHM...............................
# (167/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 5.0, bmf: WANG...............................
# (168/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 7.0, bmf: DAS...............................
# (169/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 7.0, bmf: NAIR...............................
# (170/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 7.0, bmf: STROHM...............................
# (171/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 7.0, bmf: WANG...............................
# (172/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 9.0, bmf: DAS...............................
# (173/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 9.0, bmf: NAIR...............................
# (174/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 9.0, bmf: STROHM...............................
# (175/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 9.0, bmf: WANG...............................
# (176/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 11.0, bmf: DAS...............................
# (177/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 11.0, bmf: NAIR...............................
# (178/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 11.0, bmf: STROHM...............................
# (179/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 11.0, bmf: WANG...............................
# (180/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 13.0, bmf: DAS...............................
# (181/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 13.0, bmf: NAIR...............................
# (182/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 13.0, bmf: STROHM...............................
# (183/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 13.0, bmf: WANG...............................
# (184/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 15.0, bmf: DAS...............................
# (185/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 15.0, bmf: NAIR...............................
# (186/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 15.0, bmf: STROHM...............................
# (187/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 15.0, bmf: WANG...............................
# (188/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 17.0, bmf: DAS...............................
# (189/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 17.0, bmf: NAIR...............................
# (190/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 17.0, bmf: STROHM...............................
# (191/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 17.0, bmf: WANG...............................
# (192/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 19.0, bmf: DAS...............................
# (193/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 19.0, bmf: NAIR...............................
# (194/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 19.0, bmf: STROHM...............................
# (195/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 19.0, bmf: WANG...............................
# (196/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 21.0, bmf: DAS...............................
# (197/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 21.0, bmf: NAIR...............................
# (198/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 21.0, bmf: STROHM...............................
# (199/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 11.0, patch_distance: 21.0, bmf: WANG...............................
# (200/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 3.0, bmf: DAS...............................
# (201/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 3.0, bmf: NAIR...............................
# (202/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 3.0, bmf: STROHM...............................
# (203/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 3.0, bmf: WANG...............................
# (204/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 5.0, bmf: DAS...............................
# (205/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 5.0, bmf: NAIR...............................
# (206/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 5.0, bmf: STROHM...............................
# (207/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 5.0, bmf: WANG...............................
# (208/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 7.0, bmf: DAS...............................
# (209/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 7.0, bmf: NAIR...............................
# (210/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 7.0, bmf: STROHM...............................
# (211/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 7.0, bmf: WANG...............................
# (212/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 9.0, bmf: DAS...............................
# (213/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 9.0, bmf: NAIR...............................
# (214/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 9.0, bmf: STROHM...............................
# (215/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 9.0, bmf: WANG...............................
# (216/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 11.0, bmf: DAS...............................
# (217/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 11.0, bmf: NAIR...............................
# (218/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 11.0, bmf: STROHM...............................
# (219/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 11.0, bmf: WANG...............................
# (220/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 13.0, bmf: DAS...............................
# (221/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 13.0, bmf: NAIR...............................
# (222/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 13.0, bmf: STROHM...............................
# (223/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 13.0, bmf: WANG...............................
# (224/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 15.0, bmf: DAS...............................
# (225/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 15.0, bmf: NAIR...............................
# (226/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 15.0, bmf: STROHM...............................
# (227/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 15.0, bmf: WANG...............................
# (228/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 17.0, bmf: DAS...............................
# (229/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 17.0, bmf: NAIR...............................
# (230/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 17.0, bmf: STROHM...............................
# (231/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 17.0, bmf: WANG...............................
# (232/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 19.0, bmf: DAS...............................
# (233/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 19.0, bmf: NAIR...............................
# (234/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 19.0, bmf: STROHM...............................
# (235/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 19.0, bmf: WANG...............................
# (236/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 21.0, bmf: DAS...............................
# (237/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 21.0, bmf: NAIR...............................
# (238/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 21.0, bmf: STROHM...............................
# (239/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 13.0, patch_distance: 21.0, bmf: WANG...............................
# (240/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 3.0, bmf: DAS...............................
# (241/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 3.0, bmf: NAIR...............................
# (242/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 3.0, bmf: STROHM...............................
# (243/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 3.0, bmf: WANG...............................
# (244/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 5.0, bmf: DAS...............................
# (245/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 5.0, bmf: NAIR...............................
# (246/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 5.0, bmf: STROHM...............................
# (247/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 5.0, bmf: WANG...............................
# (248/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 7.0, bmf: DAS...............................
# (249/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 7.0, bmf: NAIR...............................
# (250/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 7.0, bmf: STROHM...............................
# (251/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 7.0, bmf: WANG...............................
# (252/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 9.0, bmf: DAS...............................
# (253/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 9.0, bmf: NAIR...............................
# (254/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 9.0, bmf: STROHM...............................
# (255/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 9.0, bmf: WANG...............................
# (256/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 11.0, bmf: DAS...............................
# (257/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 11.0, bmf: NAIR...............................
# (258/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 11.0, bmf: STROHM...............................
# (259/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 11.0, bmf: WANG...............................
# (260/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 13.0, bmf: DAS...............................
# (261/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 13.0, bmf: NAIR...............................
# (262/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 13.0, bmf: STROHM...............................
# (263/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 13.0, bmf: WANG...............................
# (264/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 15.0, bmf: DAS...............................
# (265/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 15.0, bmf: NAIR...............................
# (266/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 15.0, bmf: STROHM...............................
# (267/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 15.0, bmf: WANG...............................
# (268/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 17.0, bmf: DAS...............................
# (269/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 17.0, bmf: NAIR...............................
# (270/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 17.0, bmf: STROHM...............................
# (271/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 17.0, bmf: WANG...............................
# (272/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 19.0, bmf: DAS...............................
# (273/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 19.0, bmf: NAIR...............................
# (274/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 19.0, bmf: STROHM...............................
# (275/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 19.0, bmf: WANG...............................
# (276/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 21.0, bmf: DAS...............................
# (277/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 21.0, bmf: NAIR...............................
# (278/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 21.0, bmf: STROHM...............................
# (279/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.01, patch_size: 15.0, patch_distance: 21.0, bmf: WANG...............................
# (280/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 3.0, bmf: DAS...............................
# (281/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 3.0, bmf: NAIR...............................
# (282/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 3.0, bmf: STROHM...............................
# (283/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 3.0, bmf: WANG...............................
# (284/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 5.0, bmf: DAS...............................
# (285/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 5.0, bmf: NAIR...............................
# (286/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 5.0, bmf: STROHM...............................
# (287/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 5.0, bmf: WANG...............................
# (288/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 7.0, bmf: DAS...............................
# (289/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 7.0, bmf: NAIR...............................
# (290/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 7.0, bmf: STROHM...............................
# (291/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 7.0, bmf: WANG...............................
# (292/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 9.0, bmf: DAS...............................
# (293/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 9.0, bmf: NAIR...............................
# (294/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 9.0, bmf: STROHM...............................
# (295/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 9.0, bmf: WANG...............................
# (296/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 11.0, bmf: DAS...............................
# (297/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 11.0, bmf: NAIR...............................
# (298/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 11.0, bmf: STROHM...............................
# (299/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 11.0, bmf: WANG...............................
# (300/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 13.0, bmf: DAS...............................
# (301/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 13.0, bmf: NAIR...............................
# (302/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 13.0, bmf: STROHM...............................
# (303/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 13.0, bmf: WANG...............................
# (304/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 15.0, bmf: DAS...............................
# (305/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 15.0, bmf: NAIR...............................
# (306/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 15.0, bmf: STROHM...............................
# (307/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 15.0, bmf: WANG...............................
# (308/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 17.0, bmf: DAS...............................
# (309/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 17.0, bmf: NAIR...............................
# (310/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 17.0, bmf: STROHM...............................
# (311/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 17.0, bmf: WANG...............................
# (312/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 19.0, bmf: DAS...............................
# (313/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 19.0, bmf: NAIR...............................
# (314/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 19.0, bmf: STROHM...............................
# (315/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 19.0, bmf: WANG...............................
# (316/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 21.0, bmf: DAS...............................
# (317/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 21.0, bmf: NAIR...............................
# (318/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 21.0, bmf: STROHM...............................
# (319/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 3.0, patch_distance: 21.0, bmf: WANG...............................
# (320/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 3.0, bmf: DAS...............................
# (321/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 3.0, bmf: NAIR...............................
# (322/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 3.0, bmf: STROHM...............................
# (323/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 3.0, bmf: WANG...............................
# (324/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 5.0, bmf: DAS...............................
# (325/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 5.0, bmf: NAIR...............................
# (326/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 5.0, bmf: STROHM...............................
# (327/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 5.0, bmf: WANG...............................
# (328/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 7.0, bmf: DAS...............................
# (329/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 7.0, bmf: NAIR...............................
# (330/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 7.0, bmf: STROHM...............................
# (331/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 7.0, bmf: WANG...............................
# (332/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 9.0, bmf: DAS...............................
# (333/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 9.0, bmf: NAIR...............................
# (334/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 9.0, bmf: STROHM...............................
# (335/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 9.0, bmf: WANG...............................
# (336/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 11.0, bmf: DAS...............................
# (337/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 11.0, bmf: NAIR...............................
# (338/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 11.0, bmf: STROHM...............................
# (339/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 11.0, bmf: WANG...............................
# (340/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 13.0, bmf: DAS...............................
# (341/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 13.0, bmf: NAIR...............................
# (342/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 13.0, bmf: STROHM...............................
# (343/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 13.0, bmf: WANG...............................
# (344/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 15.0, bmf: DAS...............................
# (345/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 15.0, bmf: NAIR...............................
# (346/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 15.0, bmf: STROHM...............................
# (347/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 15.0, bmf: WANG...............................
# (348/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 17.0, bmf: DAS...............................
# (349/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 17.0, bmf: NAIR...............................
# (350/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 17.0, bmf: STROHM...............................
# (351/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 17.0, bmf: WANG...............................
# (352/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 19.0, bmf: DAS...............................
# (353/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 19.0, bmf: NAIR...............................
# (354/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 19.0, bmf: STROHM...............................
# (355/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 19.0, bmf: WANG...............................
# (356/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 21.0, bmf: DAS...............................
# (357/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.03, patch_size: 5.0, patch_distance: 21.0, bmf: NAIR...............................
# ...
# (2963/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 3.0, bmf: WANG...............................
# (2964/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 5.0, bmf: DAS...............................
# (2965/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 5.0, bmf: NAIR...............................
# (2966/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 5.0, bmf: STROHM...............................
# (2967/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 5.0, bmf: WANG...............................
# (2968/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 7.0, bmf: DAS...............................
# (2969/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 7.0, bmf: NAIR...............................
# (2970/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 7.0, bmf: STROHM...............................
# (2971/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 7.0, bmf: WANG...............................
# (2972/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 9.0, bmf: DAS...............................
# (2973/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 9.0, bmf: NAIR...............................
# (2974/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 9.0, bmf: STROHM...............................
# (2975/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 9.0, bmf: WANG...............................
# (2976/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 11.0, bmf: DAS...............................
# (2977/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 11.0, bmf: NAIR...............................
# (2978/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 11.0, bmf: STROHM...............................
# (2979/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 11.0, bmf: WANG...............................
# (2980/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 13.0, bmf: DAS...............................
# (2981/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 13.0, bmf: NAIR...............................
# (2982/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 13.0, bmf: STROHM...............................
# (2983/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 13.0, bmf: WANG...............................
# (2984/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 15.0, bmf: DAS...............................
# (2985/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 15.0, bmf: NAIR...............................
# (2986/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 15.0, bmf: STROHM...............................
# (2987/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 15.0, bmf: WANG...............................
# (2988/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 17.0, bmf: DAS...............................
# (2989/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 17.0, bmf: NAIR...............................
# (2990/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 17.0, bmf: STROHM...............................
# (2991/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 17.0, bmf: WANG...............................
# (2992/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 19.0, bmf: DAS...............................
# (2993/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 19.0, bmf: NAIR...............................
# (2994/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 19.0, bmf: STROHM...............................
# (2995/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 19.0, bmf: WANG...............................
# (2996/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 21.0, bmf: DAS...............................
# (2997/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 21.0, bmf: NAIR...............................
# (2998/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 21.0, bmf: STROHM...............................
# (2999/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 11.0, patch_distance: 21.0, bmf: WANG...............................
# (3000/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 3.0, bmf: DAS...............................
# (3001/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 3.0, bmf: NAIR...............................
# (3002/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 3.0, bmf: STROHM...............................
# (3003/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 3.0, bmf: WANG...............................
# (3004/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 5.0, bmf: DAS...............................
# (3005/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 5.0, bmf: NAIR...............................
# (3006/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 5.0, bmf: STROHM...............................
# (3007/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 5.0, bmf: WANG...............................
# (3008/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 7.0, bmf: DAS...............................
# (3009/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 7.0, bmf: NAIR...............................
# (3010/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 7.0, bmf: STROHM...............................
# (3011/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 7.0, bmf: WANG...............................
# (3012/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 9.0, bmf: DAS...............................
# (3013/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 9.0, bmf: NAIR...............................
# (3014/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 9.0, bmf: STROHM...............................
# (3015/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 9.0, bmf: WANG...............................
# (3016/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 11.0, bmf: DAS...............................
# (3017/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 11.0, bmf: NAIR...............................
# (3018/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 11.0, bmf: STROHM...............................
# (3019/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 11.0, bmf: WANG...............................
# (3020/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 13.0, bmf: DAS...............................
# (3021/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 13.0, bmf: NAIR...............................
# (3022/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 13.0, bmf: STROHM...............................
# (3023/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 13.0, bmf: WANG...............................
# (3024/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 15.0, bmf: DAS...............................
# (3025/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 15.0, bmf: NAIR...............................
# (3026/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 15.0, bmf: STROHM...............................
# (3027/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 15.0, bmf: WANG...............................
# (3028/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 17.0, bmf: DAS...............................
# (3029/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 17.0, bmf: NAIR...............................
# (3030/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 17.0, bmf: STROHM...............................
# (3031/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 17.0, bmf: WANG...............................
# (3032/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 19.0, bmf: DAS...............................
# (3033/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 19.0, bmf: NAIR...............................
# (3034/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 19.0, bmf: STROHM...............................
# (3035/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 19.0, bmf: WANG...............................
# (3036/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 21.0, bmf: DAS...............................
# (3037/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 21.0, bmf: NAIR...............................
# (3038/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 21.0, bmf: STROHM...............................
# (3039/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 13.0, patch_distance: 21.0, bmf: WANG...............................
# (3040/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 3.0, bmf: DAS...............................
# (3041/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 3.0, bmf: NAIR...............................
# (3042/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 3.0, bmf: STROHM...............................
# (3043/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 3.0, bmf: WANG...............................
# (3044/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 5.0, bmf: DAS...............................
# (3045/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 5.0, bmf: NAIR...............................
# (3046/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 5.0, bmf: STROHM...............................
# (3047/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 5.0, bmf: WANG...............................
# (3048/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 7.0, bmf: DAS...............................
# (3049/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 7.0, bmf: NAIR...............................
# (3050/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 7.0, bmf: STROHM...............................
# (3051/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 7.0, bmf: WANG...............................
# (3052/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 9.0, bmf: DAS...............................
# (3053/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 9.0, bmf: NAIR...............................
# (3054/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 9.0, bmf: STROHM...............................
# (3055/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 9.0, bmf: WANG...............................
# (3056/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 11.0, bmf: DAS...............................
# (3057/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 11.0, bmf: NAIR...............................
# (3058/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 11.0, bmf: STROHM...............................
# (3059/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 11.0, bmf: WANG...............................
# (3060/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 13.0, bmf: DAS...............................
# (3061/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 13.0, bmf: NAIR...............................
# (3062/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 13.0, bmf: STROHM...............................
# (3063/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 13.0, bmf: WANG...............................
# (3064/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 15.0, bmf: DAS...............................
# (3065/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 15.0, bmf: NAIR...............................
# (3066/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 15.0, bmf: STROHM...............................
# (3067/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 15.0, bmf: WANG...............................
# (3068/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 17.0, bmf: DAS...............................
# (3069/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 17.0, bmf: NAIR...............................
# (3070/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 17.0, bmf: STROHM...............................
# (3071/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 17.0, bmf: WANG...............................
# (3072/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 19.0, bmf: DAS...............................
# (3073/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 19.0, bmf: NAIR...............................
# (3074/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 19.0, bmf: STROHM...............................
# (3075/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 19.0, bmf: WANG...............................
# (3076/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 21.0, bmf: DAS...............................
# (3077/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 21.0, bmf: NAIR...............................
# (3078/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 21.0, bmf: STROHM...............................
# (3079/3080) - hsname: IS_L11-4v_data3_RF.h5, h: 0.21, patch_size: 15.0, patch_distance: 21.0, bmf: WANG...............................

# %%
df[df['iou'] == df['iou'].max()]
# Out:
#           h  patch_size  patch_distance  threshold  name       iou
# 42142  0.09        13.0            21.0       0.53  WANG  0.323575

# %%
df.groupby('name')['iou'].max()
# Out:
# name
# DAS       0.185008
# NAIR      0.216577
# STROHM    0.194154
# WANG      0.323575
# Name: iou, dtype: float64

# %%
max_iou_index = df.groupby('name')['iou'].idxmax()
result_df = df.loc[max_iou_index]
result_df
# Out:
#           h  patch_size  patch_distance  threshold    name       iou
# 53598  0.13         5.0             7.0       0.70     DAS  0.185008
# 94794  0.21        15.0            11.0       0.67    NAIR  0.216577
# 51672  0.11        15.0            15.0       0.66  STROHM  0.194154
# 42142  0.09        13.0            21.0       0.53    WANG  0.323575

# %%
result_df['dice'] = 2*result_df['iou']/(1+result_df['iou'])

# %%
result_df
# Out:
#           h  patch_size  patch_distance  threshold    name       iou      dice
# 53598  0.13         5.0             7.0       0.70     DAS  0.185008  0.312248
# 94794  0.21        15.0            11.0       0.67    NAIR  0.216577  0.356044
# 51672  0.11        15.0            15.0       0.66  STROHM  0.194154  0.325174
# 42142  0.09        13.0            21.0       0.53    WANG  0.323575  0.488941
